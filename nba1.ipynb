# %% [markdown]
# <a href="https://colab.research.google.com/github/amiguelnobrega/Nba/blob/main/nba1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Package Import

# %%
# Import pandas.

import pandas as pd

# %%
# Mount Google Drive in colab notebook

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Get .csv from gdrive

data = pd.read_csv('/content/gdrive/Othercomputers/My MacBook Air/Estudo/Google Advance DA/Projects/NBA/nba-players.csv', index_col=0)
print('done!')
# Out:
# done!

# %% [markdown]
# #Data Exploration

# %%
# Display first 10 rows of data.

data.head(10)
# Out:
#               name  gp   min  pts  fgm  fga    fg  3p_made  3pa    3p  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
# 5     Tony Bennett  75  11.4  3.7  1.5  3.5  42.3      0.3  1.1  32.5  ...
# 6      Don MacLean  62  10.9  6.6  2.5  5.8  43.5      0.0  0.1  50.0  ...
# 7     Tracy Murray  48  10.3  5.7  2.3  5.4  41.5      0.4  1.5  30.0  ...
# 8     Duane Cooper  65   9.9  2.4  1.0  2.4  39.2      0.1  0.5  23.3  ...
# 9     Dave Johnson  42   8.5  3.7  1.4  3.5  38.3      0.1  0.3  21.4  ...
#
#    fta    ft  oreb  dreb  reb  ast  stl  blk  tov  target_5yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3            0
# ...

# %%
# Display number of rows, number of columns.

data.shape
# Out:
# (1340, 21)

# %%
# Display all column names.

data.columns
# Out:
# Index(['name', 'gp', 'min', 'pts', 'fgm', 'fga', 'fg', '3p_made', '3pa', '3p',
#        'ftm', 'fta', 'ft', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'tov',
#        'target_5yrs'],
#       dtype='object')

# %% [markdown]
# ###The following table provides a description of the data in each column:

# %% [markdown]
# Column Name |     Column Description
# ---         |     ---
# 1. name| 	        Name of NBA player
# 2. gp|  	        Number of games played
# 3. min|  	        Number of minutes played per game
# 4. pts|  	        Average number of points per game
# 5. fgm|  	        Average number of field goals made per game
# 6. fga|  	        Average number of field goal attempts per game
# 7. fg|	          Average percent of field goals made per game
# 8. 3p_made|	      Average number of three-point field goals made per game
# 9. 3pa|           Average number of three-point field goal attempts per game
# 10. 3p|	          Average percent of three-point field goals made per game
# 11. ftm|	        Average number of free throws made per game
# 12. fta|	        Average number of free throw attempts per game
# 13. ft|           Average percent of free throws made per game
# 14. oreb|	        Average number of offensive rebounds per game
# 15. dreb|	        Average number of defensive rebounds per game
# 16. reb|	        Average number of rebounds per game
# 17. ast|	        Average number of assists per game
# 18. stl|	        Average number of steals per game
# 19. blk|	        Average number of blocks per game
# 20. tov|	        Average number of turnovers per game
# 21. target_5yrs|	1 if career duration >= 5 yrs, 0 otherwise

# %%
# Use .info() to display a summary of the DataFrame.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1340 entries, 0 to 1339
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1340 non-null   object
#  1   gp           1340 non-null   int64
#  2   min          1340 non-null   float64
#  3   pts          1340 non-null   float64
#  4   fgm          1340 non-null   float64
#  5   fga          1340 non-null   float64
#  6   fg           1340 non-null   float64
#  7   3p_made      1340 non-null   float64
#  8   3pa          1340 non-null   float64
#  9   3p           1340 non-null   float64
#  10  ftm          1340 non-null   float64
#  11  fta          1340 non-null   float64
#  12  ft           1340 non-null   float64
#  13  oreb         1340 non-null   float64
#  14  dreb         1340 non-null   float64
#  15  reb          1340 non-null   float64
#  16  ast          1340 non-null   float64
#  17  stl          1340 non-null   float64
# ...

# %% [markdown]
# ###Based on the preceding tables, the name column is categorical, and the rest of the columns are numerical.

# %% [markdown]
# ###Check for missing values

# %%
# Display the number of missing values in each column.
# Check whether each value is missing.
# Aggregate the number of missing values per column.

data.isna().sum()
# Out:
# name           0
# gp             0
# min            0
# pts            0
# fgm            0
# fga            0
# fg             0
# 3p_made        0
# 3pa            0
# 3p             0
# ftm            0
# fta            0
# ft             0
# oreb           0
# dreb           0
# reb            0
# ast            0
# stl            0
# blk            0
# tov            0
# target_5yrs    0
# dtype: int64

# %% [markdown]
# #Statistical Tests

# %%
# Display percentage (%) of values for each class (1, 0) represented in the target column of this dataset.

data["target_5yrs"].value_counts(normalize=True)*100
# Out:
# target_5yrs
# 1    62.014925
# 0    37.985075
# Name: proportion, dtype: float64

# %% [markdown]
# ###The dataset is not perfectly balanced but a 62-38 split is not too imbalanced

# %% [markdown]
# #Results and Evaluation

# %% [markdown]
# ### At this stage of the feature engineering process, it would be most effective to select the following columns:
#
# ### gp, min, pts, fg, 3p, ft, reb, ast, stl, blk, tov.

# %% [markdown]
# Column Name |     Column Description
# ---         |     ---
# 2. gp|  	        Number of games played
# 3. min|  	        Number of minutes played per game
# 4. pts|  	        Average number of points per game
# 7. fg|	          Average percent of field goals made per game
# 10. 3p|	          Average percent of three-point field goals made per game
# 13. ft|           Average percent of free throws made per game
# 16. reb|	        Average number of rebounds per game
# 17. ast|	        Average number of assists per game
# 18. stl|	        Average number of steals per game
# 19. blk|	        Average number of blocks per game
# 20. tov|	        Average number of turnovers per game

# %%
# Select the columns to proceed with and save the DataFrame in new variable `selected_data`.
# Include the target column, `target_5yrs`.

selected_data = data[["gp", "min", "pts", "fg", "3p", "ft", "reb", "ast", "stl", "blk", "tov", "target_5yrs"]]

# Display the first few rows.

selected_data.head()
# Out:
#    gp   min  pts    fg    3p    ft  reb  ast  stl  blk  tov  target_5yrs
# 0  36  27.4  7.4  34.7  25.0  69.9  4.1  1.9  0.4  0.4  1.3            0
# 1  35  26.9  7.2  29.6  23.5  76.5  2.4  3.7  1.1  0.5  1.6            0
# 2  74  15.3  5.2  42.2  24.4  67.0  2.2  1.0  0.5  0.3  1.0            0
# 3  58  11.6  5.7  42.6  22.6  68.9  1.9  0.8  0.6  0.1  1.0            1
# 4  48  11.5  4.5  52.4   0.0  67.4  2.5  0.3  0.3  0.4  0.8            1

# %%
# Display the first few rows of `selected_data` for reference.

selected_data.head()
# Out:
#    gp   min  pts    fg    3p    ft  reb  ast  stl  blk  tov  target_5yrs
# 0  36  27.4  7.4  34.7  25.0  69.9  4.1  1.9  0.4  0.4  1.3            0
# 1  35  26.9  7.2  29.6  23.5  76.5  2.4  3.7  1.1  0.5  1.6            0
# 2  74  15.3  5.2  42.2  24.4  67.0  2.2  1.0  0.5  0.3  1.0            0
# 3  58  11.6  5.7  42.6  22.6  68.9  1.9  0.8  0.6  0.1  1.0            1
# 4  48  11.5  4.5  52.4   0.0  67.4  2.5  0.3  0.3  0.4  0.8            1

# %%
# Extract two features that would help predict target_5yrs.
# Create a new variable named `extracted_data`.

# Make a copy of `selected_data`
extracted_data = selected_data.copy()

# Add a new column named `total_points`;
# Calculate total points earned by multiplying the number of games played by the average number of points earned per game
extracted_data["total_points"] = extracted_data["gp"] * extracted_data["pts"]

# Add a new column named `efficiency`. Calculate efficiency by dividing the total points earned by the total number
# of minutes played, which yields points per minute. (Note that `min` represents avg. minutes per game.)
extracted_data["efficiency"] = extracted_data["total_points"] / (extracted_data["min"] * extracted_data["gp"])

# Display the first few rows of `extracted_data` to confirm that the new columns were added.
extracted_data.head()
# Out:
#    gp   min  pts    fg    3p    ft  reb  ast  stl  blk  tov  target_5yrs  \
# 0  36  27.4  7.4  34.7  25.0  69.9  4.1  1.9  0.4  0.4  1.3            0
# 1  35  26.9  7.2  29.6  23.5  76.5  2.4  3.7  1.1  0.5  1.6            0
# 2  74  15.3  5.2  42.2  24.4  67.0  2.2  1.0  0.5  0.3  1.0            0
# 3  58  11.6  5.7  42.6  22.6  68.9  1.9  0.8  0.6  0.1  1.0            1
# 4  48  11.5  4.5  52.4   0.0  67.4  2.5  0.3  0.3  0.4  0.8            1
#
#    total_points  efficiency
# 0         266.4    0.270073
# 1         252.0    0.267658
# 2         384.8    0.339869
# 3         330.6    0.491379
# 4         216.0    0.391304

# %%
# Remove any columns from `extracted_data` that are no longer needed.

# Remove `gp`, `pts`, and `min` from `extracted_data`.
extracted_data = extracted_data.drop(columns=["gp", "pts", "min"])

# Display the first few rows of `extracted_data` to ensure that column drops took place.

extracted_data.head()
# Out:
#      fg    3p    ft  reb  ast  stl  blk  tov  target_5yrs  total_points  \
# 0  34.7  25.0  69.9  4.1  1.9  0.4  0.4  1.3            0         266.4
# 1  29.6  23.5  76.5  2.4  3.7  1.1  0.5  1.6            0         252.0
# 2  42.2  24.4  67.0  2.2  1.0  0.5  0.3  1.0            0         384.8
# 3  42.6  22.6  68.9  1.9  0.8  0.6  0.1  1.0            1         330.6
# 4  52.4   0.0  67.4  2.5  0.3  0.3  0.4  0.8            1         216.0
#
#    efficiency
# 0    0.270073
# 1    0.267658
# 2    0.339869
# 3    0.491379
# 4    0.391304
